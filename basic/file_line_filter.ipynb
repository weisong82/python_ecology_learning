# %%
# -*- coding: utf-8 -*-

# %%
#过滤每行含有href的写到新文件
with open('out_file.json', 'w') as f:
    f.write(''.join([line for line in open('out.json').readlines() if 'href' in line]))

# %%
#试试分开
def filterHREF(line):
    return  'href' in line

with open('out_file.json', 'r') as f:
    #f.readlines(filter=filterHREF())
    lines = filter(filterHREF,f.readlines())
    f.write(''.join( lines ))

# %%
print(''.join([line for line in open('nohup.out').readlines() if 'http' in line]))
# Out:
# [I 15:44:04.721 NotebookApp] http://0.0.0.0:8888/
# [W 16:34:48.786 NotebookApp] 404 GET /i18n/zh-CN/LC_MESSAGES/nbjs.json?v=20171123154404 (103.7.29.8) 2.00ms referer=http://119.28.137.45:8888/tree?
# [W 16:34:48.788 NotebookApp] 404 GET /static/components/moment/locale/zh-cn.js?v=20171123154404 (103.7.29.8) 1.85ms referer=http://119.28.137.45:8888/tree?
# [W 16:35:14.016 NotebookApp] 404 GET /static/components/moment/locale/zh-cn.js?v=20171123154404 (103.7.29.8) 1.31ms referer=http://119.28.137.45:8888/edit/nohup.out
# [W 16:35:14.089 NotebookApp] 404 GET /i18n/zh-CN/LC_MESSAGES/nbjs.json?v=20171123154404 (103.7.29.8) 1.48ms referer=http://119.28.137.45:8888/edit/nohup.out
# [W 16:35:39.600 NotebookApp] 404 GET /nbextensions/widgets/notebook/js/extension.js?v=20171123154404 (103.7.29.8) 1.79ms referer=http://119.28.137.45:8888/notebooks/Untitled.ipynb
# ...

# %%
b=['12' '2']

# %%
b
# Out:
# ['122']

# %%
type(b)
# Out:
# list

# %%
print(b.pop())
# Out:
# <built-in method pop of list object at 0x7f4a6820d1c8>
