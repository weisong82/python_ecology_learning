# %% [markdown]
# # http://pbpython.com/pandas_transform.html
#
# [img]http://pbpython.com/images/transform-example.png

# %%
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
df = pd.read_excel("./sales_transactions.xlsx")

# %%
import xlrd
xlrd.__VERSION__
# Out:
# '1.1.0'

# %%
df.columns
df.count()
df.head()
# Out:
# Index(['account', 'name', 'order', 'sku', 'quantity', 'unit price',
#        'ext price'],
#       dtype='object')
# account       12
# name          12
# order         12
# sku           12
# quantity      12
# unit price    12
# ext price     12
# dtype: int64
#    account           name  order       sku  quantity  unit price  ext price
# 0   383080       Will LLC  10001  B1-20000         7       33.69     235.83
# 1   383080       Will LLC  10001  S1-27722        11       21.12     232.32
# 2   383080       Will LLC  10001  B1-86481         3       35.99     107.97
# 3   412290  Jerde-Hilpert  10005  S1-06532        48       55.82    2679.36
# 4   412290  Jerde-Hilpert  10005  S1-82801        21       13.62     286.02

# %%
df.groupby('order')["ext price"].sum()
# Out:
# order
# 10001     576.12
# 10005    8185.49
# 10006    3724.49
# Name: ext price, dtype: float64

# %%
order_total = df.groupby('order')["ext price"].sum().rename("Order_Total").reset_index()
order_total.head()
# Out:
#    order  Order_Total
# 0  10001       576.12
# 1  10005      8185.49
# 2  10006      3724.49

# %%
df_1 = df.merge(order_total)
df_1["Percent_of_Order"] = df_1["ext price"] / df_1["Order_Total"]
df_1.head()
# Out:
#    account           name  order       sku  quantity  unit price  ext price  \
# 0   383080       Will LLC  10001  B1-20000         7       33.69     235.83
# 1   383080       Will LLC  10001  S1-27722        11       21.12     232.32
# 2   383080       Will LLC  10001  B1-86481         3       35.99     107.97
# 3   412290  Jerde-Hilpert  10005  S1-06532        48       55.82    2679.36
# 4   412290  Jerde-Hilpert  10005  S1-82801        21       13.62     286.02
#
#    Order_Total  Percent_of_Order
# 0       576.12          0.409342
# 1       576.12          0.403249
# 2       576.12          0.187409
# 3      8185.49          0.327330
# 4      8185.49          0.034942

# %%
#Second Approach - Using Transform 保留了原始DF的序列号
dt =df.groupby('order')["ext price"].transform('sum')
dt
# Out:
# 0      576.12
# 1      576.12
# 2      576.12
# 3     8185.49
# 4     8185.49
# 5     8185.49
# 6     8185.49
# 7     8185.49
# 8     3724.49
# 9     3724.49
# 10    3724.49
# 11    3724.49
# Name: ext price, dtype: float64

# %%
df["Order_Total"] = df.groupby('order')["ext price"].transform('sum')
df["Percent_of_Order"] = df["ext price"] / df["Order_Total"]
df
# Out:
#     account           name  order       sku  quantity  unit price  ext price  \
# 0    383080       Will LLC  10001  B1-20000         7       33.69     235.83
# 1    383080       Will LLC  10001  S1-27722        11       21.12     232.32
# 2    383080       Will LLC  10001  B1-86481         3       35.99     107.97
# 3    412290  Jerde-Hilpert  10005  S1-06532        48       55.82    2679.36
# 4    412290  Jerde-Hilpert  10005  S1-82801        21       13.62     286.02
# 5    412290  Jerde-Hilpert  10005  S1-06532         9       92.55     832.95
# 6    412290  Jerde-Hilpert  10005  S1-47412        44       78.91    3472.04
# 7    412290  Jerde-Hilpert  10005  S1-27722        36       25.42     915.12
# 8    218895      Kulas Inc  10006  S1-27722        32       95.66    3061.12
# 9    218895      Kulas Inc  10006  B1-33087        23       22.55     518.65
# 10   218895      Kulas Inc  10006  B1-33364         3       72.30     216.90
# ...
